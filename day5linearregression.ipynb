# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 #Reading Data
data=pd.read_csv('data.csv')
data.head()
# collecting X and Y
x=data['Head Size(cm^3)'].values
y=data['Brain Weight(grams)'].values
# calcuting coffecient
#mean x and y
mean_x=np.mean(x)
mean_y=np.mean(y)
# total number of values
n=len(x)
#using the formula to calculate b1 and b2
numer=0
denom=0
for i in range(n):
    numer+=(x[i]-mean_x)*(y[i]-mean_y)
    denom+=(x[i]-mean_x)**2
b1=numer/denom
b0=mean_y-(b1*mean_x)
#printing coeffecient
print("coefficients")
print(b1,b0)
#plotting values and regression line
max_x=np.max(x)+100
min_x=np.min(x)-100
#calculating line values x and y
y=b0+b1*x
#ploting line
plt.plot(x,y,color='#58b970',label='Regression Line')
#plotting scatter points
plt.scatter(x,y,c='#ef5423',label='Scatter Plot')
# Out:
# coefficients
# 0.26342933948939945 325.57342104944223

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Reading Data
data = pd.read_csv('data.csv')
data.head()

# Collecting X and Y
X = data['Head Size(cm^3)'].values
Y = data['Brain Weight(grams)'].values

# Calculating coefficient

# Mean X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of values
n = len(X)

# Using the formula to calculate b1 and b2
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# Printing coefficients
print("Coefficients")
print(b1, b0)

# Plotting Values and Regression Line

max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
y = b0 + b1 * X

# Ploting Line
plt.plot(X,y , color='#58b970', label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')
# Out:
# Coefficients
# 0.26342933948939945 325.57342104944223

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# 5         1          1             3585                 1300
# 6         1          1             3785                 1400
# 7         1          1             3559                 1255
# 8         1          1             3613                 1355
# 9         1          1             3982                 1375
# 10        1          1             3443                 1340
# 11        1          1             3993                 1380
# 12        1          1             3640                 1355
# 13        1          1             4208                 1522
# ...

# %%
df=pd.read_csv('Ecommerce Customers')

# %%
df
# Out:
#                                Email  \
# 0          mstephenson@fernandez.com
# 1                  hduke@hotmail.com
# 2                   pallen@yahoo.com
# 3            riverarebecca@gmail.com
# 4      mstephens@davidson-herman.com
# 5             alvareznancy@lucas.biz
# 6              katherine20@yahoo.com
# 7                 awatkins@yahoo.com
# 8        vchurch@walter-martinez.com
# 9                   bonnie69@lin.biz
# 10             andrew06@peterson.com
# 11            ryanwerner@freeman.biz
# 12                 knelson@gmail.com
# 13             wrightpeter@yahoo.com
# 14             taylormason@gmail.com
# 15               jstark@anderson.com
# 16               wjennings@gmail.com
# 17          rebecca45@hale-bauer.biz
# 18           alejandro75@hotmail.com
# 19            samuel46@love-west.net
# 20                 megan33@gmail.com
# 21                 agolden@yahoo.com
# 22             vstafford@hotmail.com
# 23   denise22@hernandez-townsend.com
# ...

# %%
df=pd.read_csv('USA_Housing.csv')
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# 6         64698.463428             6.025336                   8.147760
# 7         78394.339278             6.989780                   6.620478
# 8         59927.660813             5.362126                   6.393121
# 9         81885.927184             4.423672                   8.167688
# 10        80527.472083             8.093513                   5.042747
# 11        50593.695497             4.496513                   7.467627
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('USA_Housing.csv')
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# 6         64698.463428             6.025336                   8.147760
# 7         78394.339278             6.989780                   6.620478
# 8         59927.660813             5.362126                   6.393121
# 9         81885.927184             4.423672                   8.167688
# 10        80527.472083             8.093513                   5.042747
# 11        50593.695497             4.496513                   7.467627
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg. Area Income                5000 non-null float64
# Avg. Area House Age             5000 non-null float64
# Avg. Area Number of Rooms       5000 non-null float64
# Avg. Area Number of Bedrooms    5000 non-null float64
# Area Population                 5000 non-null float64
# Price                           5000 non-null float64
# Address                         5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 273.5+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\LENOVO\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.heatmap(df.corr())

# %%
x=df[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]
y=df['Price']

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
# 5       1.068138e+06
# 6       1.502056e+06
# 7       1.573937e+06
# 8       7.988695e+05
# 9       1.545155e+06
# 10      1.707046e+06
# 11      6.637324e+05
# 12      1.042814e+06
# 13      1.291332e+06
# 14      1.402818e+06
# 15      1.306675e+06
# 16      1.556787e+06
# 17      5.284852e+05
# 18      1.019426e+06
# 19      1.030591e+06
# 20      2.146925e+06
# 21      9.292476e+05
# 22      7.188872e+05
# 23      7.439998e+05
# 24      8.957371e+05
# 25      1.453975e+06
# 26      1.125693e+06
# 27      9.754295e+05
# 28      1.240764e+06
# 29      1.577018e+06
#             ...
# 4970    1.120943e+06
# 4971    1.111307e+06
# 4972    1.736402e+06
# 4973    1.340770e+06
# 4974    8.013486e+05
# 4975    1.324382e+06
# 4976    1.340344e+06
# 4977    1.518478e+06
# 4978    1.910585e+06
# 4979    1.823498e+06
# 4980    1.406865e+06
# 4981    1.203850e+06
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -2640159.796851911

# %%
coeff_df=pd.DataFrame(lm.coeff_df,X.columns,columns=['Coefficient'])
coeff_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-a776c80a6bff> in <module>()
# ----> 1 coeff_df=pd.DataFrame(lm.coeff_df,X.columns,columns=['Coefficient'])
#       2 coeff_df
#
# AttributeError: 'LinearRegression' object has no attribute 'coeff_df'

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\New folder\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\New folder\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\New folder\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
sns.baplot(x='sex',y='total_bill',data=tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-8b539a0dee43> in <module>()
# ----> 1 sns.baplot(x='sex',y='total_bill',data=tips)
#
# AttributeError: module 'seaborn' has no attribute 'baplot'

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimation=np.std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1b99d6f30a35> in <module>()
# ----> 1 sns.barplot(x='sex',y='total_bill',data=tips,estimaton=np.std)
#
# NameError: name 'tips' is not defined

# %%
sns.countplot(x='sex',data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-beaaf62647c5> in <module>()
# ----> 1 sns.countplot(x='sex',data=tips)
#
# NameError: name 'tips' is not defined

# %%
sns.boxplot(x="day",y="total",data=tips,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-46385d2c1404> in <module>()
# ----> 1 sns.boxplot(x="day",y="total",data=tips,palette='rainbow')
#
# NameError: name 'tips' is not defined

# %%
sns.boxplot(x="day",y="total",data=tips,palette='rainbow',orient='h')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-eea5f3a76725> in <module>()
# ----> 1 sns.boxplot(x="day",y="total",data=tips,palette='rainbow',orient='h')
#
# NameError: name 'tips' is not defined

# %%
sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips,palette="coolwarm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-7c5c7065f819> in <module>()
# ----> 1 sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips,palette="coolwarm")
#
# NameError: name 'tips' is not defined

# %%
sns.violinplot(x="day",y="total_bill",data=tips,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-4e30c68554aa> in <module>()
# ----> 1 sns.violinplot(x="day",y="total_bill",data=tips,palette='rainbow')
#
# NameError: name 'tips' is not defined

# %%
sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-de5cc72c4ae4> in <module>()
# ----> 1 sns.stripplot(x="day",y="total_bill",data=tips)
#
# NameError: name 'tips' is not defined

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-d1d7819bc6f6> in <module>()
# ----> 1 sns.stripplot(x="day",y="total_bill",data=tips,jitter=True)
#
# NameError: name 'tips' is not defined

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-c3219857ea96> in <module>()
# ----> 1 sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='Set1')
#
# NameError: name 'tips' is not defined

# %%
iris=sns.load_dataset('iris')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\New folder\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\New folder\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\New folder\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
df=pd.read_csv('Ecommerce Customers')

# %%
df
# Out:
#                                Email  \
# 0          mstephenson@fernandez.com
# 1                  hduke@hotmail.com
# 2                   pallen@yahoo.com
# 3            riverarebecca@gmail.com
# 4      mstephens@davidson-herman.com
# 5             alvareznancy@lucas.biz
# 6              katherine20@yahoo.com
# 7                 awatkins@yahoo.com
# 8        vchurch@walter-martinez.com
# 9                   bonnie69@lin.biz
# 10             andrew06@peterson.com
# 11            ryanwerner@freeman.biz
# 12                 knelson@gmail.com
# 13             wrightpeter@yahoo.com
# 14             taylormason@gmail.com
# 15               jstark@anderson.com
# 16               wjennings@gmail.com
# 17          rebecca45@hale-bauer.biz
# 18           alejandro75@hotmail.com
# 19            samuel46@love-west.net
# 20                 megan33@gmail.com
# 21                 agolden@yahoo.com
# 22             vstafford@hotmail.com
# 23   denise22@hernandez-townsend.com
# ...

# %%
df.mean()
# Out:
# Avg. Session Length      33.053194
# Time on App              12.052488
# Time on Website          37.060445
# Length of Membership      3.533462
# Yearly Amount Spent     499.314038
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.3+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.jointplot(x="Time on Website",y="Yearly Amount Spent",data=df)
# Out:
# C:\Users\LENOVO\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\LENOVO\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Time on App',y='Length of Membership',kind='hex',data=df)
# Out:
# C:\Users\LENOVO\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\LENOVO\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(df)

# %%
sns.lmplot(x='Length of Membership',y='Yearly Amount Spent',data=df)

# %%
'[sns.heatmap(df.corr())

# %%
y=df['Yearly Amount Spent']

# %%
x=df[['Avg.Session Length','Time on App','Time on Website','Length of Membership']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-ee1b67758d0a> in <module>()
# ----> 1 x=df[['Avg.Session Length','Time on App','Time on Website','Length of Membership']]
#
# ~\Anaconda3\New folder\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\New folder\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_test=train_test_split(X,y,test_size=0.3,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-3bd0f777cfae> in <module>()
# ----> 1 X_train,X_test,y_test=train_test_split(x,y,test_size=0.3,random_state=101)
#
# ~\Anaconda3\New folder\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2029         test_size = 0.25
#    2030
# -> 2031     arrays = indexable(*arrays)
#    2032
#    2033     if shuffle is False:
#
# ~\Anaconda3\New folder\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~\Anaconda3\New folder\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Coefficients:\n',lm.coef_)
# Out:
# Coefficients:
#  [2.15282755e+01 1.64883282e+05 1.22368678e+05 2.23380186e+03
#  1.51504200e+01]

# %%
import re
f1=open("input.txt","r")
f2=open("output.txt","w")
for line in f1:
    list=re.findall("[6-9]\d{9}]",line)
    for n in list:
        f2.write(n+"\n")
print("extracted all mobile number")
f1.close()
f2.close()
# Out:
# extracted all mobile number

# %%
df=pd.read_csv(titanic_test.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f23021edfbc> in <module>()
# ----> 1 df=pd.read_csv(titanic_test.csv)
#
# NameError: name 'pd' is not defined
